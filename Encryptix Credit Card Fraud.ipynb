# %%
import pandas as pd
card = pd.read_csv(r"C:\Users\Admin\Downloads\intern\creditcard.csv")
card
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
card.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# # VISUALIZATION

# %%
import seaborn as sns
import matplotlib.pyplot as plt
count_classes = pd.value_counts(card['Class'], sort = True).sort_index()
count_classes.plot(kind = 'bar')
plt.title("Fraud class histogram")
plt.xlabel("Class")
plt.ylabel("Frequency")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10800\3701801406.py:3: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   count_classes = pd.value_counts(card['Class'], sort = True).sort_index()
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ## Hence the dataset is clealy imbalanced so we implement oversampling

# %%
card.hist(figsize=(20, 20), bins=50)
plt.suptitle('Histograms of All Features')
plt.show()

# %% [markdown]
# # PREPROCESSING

# %%
## Seprate the target and features 
label = card["Class"]
card.drop(columns=["Class"],inplace=True)
card
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V20       V21  \
# ...

# %%
## Preprocessing the data 
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = pd.DataFrame(scaler.fit_transform(card))
scaled_data
# Out:
#               0         1         2         3         4         5         6   \
# 0      -1.996583 -0.694242 -0.044075  1.672773  0.973366 -0.245117  0.347068
# 1      -1.996583  0.608496  0.161176  0.109797  0.316523  0.043483 -0.061820
# 2      -1.996562 -0.693500 -0.811578  1.169468  0.268231 -0.364572  1.351454
# 3      -1.996562 -0.493325 -0.112169  1.182516 -0.609727 -0.007469  0.936150
# 4      -1.996541 -0.591330  0.531541  1.021412  0.284655 -0.295015  0.071999
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802  1.641931 -6.065842  6.099286 -6.486245 -1.459641 -3.886611 -1.956690
# 284803  1.641952 -0.374121 -0.033356  1.342145 -0.521651  0.629040  0.794446
# 284804  1.641974  0.980024 -0.182434 -2.143205 -0.393984  1.905833  2.275262
# 284805  1.641974 -0.122755  0.321250  0.463320  0.487192 -0.273836  0.468155
# 284806  1.642058 -0.272331 -0.114899  0.463866 -0.357570 -0.009089 -0.487602
#
# ...

# %%
## Preparing the scaled dataframe
scaled_data.columns =['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
       'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
       'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount']
scaled_data["target"] = label
scaled_data
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 0      -1.996583 -0.694242 -0.044075  1.672773  0.973366 -0.245117  0.347068
# 1      -1.996583  0.608496  0.161176  0.109797  0.316523  0.043483 -0.061820
# 2      -1.996562 -0.693500 -0.811578  1.169468  0.268231 -0.364572  1.351454
# 3      -1.996562 -0.493325 -0.112169  1.182516 -0.609727 -0.007469  0.936150
# 4      -1.996541 -0.591330  0.531541  1.021412  0.284655 -0.295015  0.071999
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802  1.641931 -6.065842  6.099286 -6.486245 -1.459641 -3.886611 -1.956690
# 284803  1.641952 -0.374121 -0.033356  1.342145 -0.521651  0.629040  0.794446
# 284804  1.641974  0.980024 -0.182434 -2.143205 -0.393984  1.905833  2.275262
# 284805  1.641974 -0.122755  0.321250  0.463320  0.487192 -0.273836  0.468155
# 284806  1.642058 -0.272331 -0.114899  0.463866 -0.357570 -0.009089 -0.487602
#
# ...

# %%
## Preparing train and test data from scaled dataframe
x = scaled_data.iloc[:,:-1]
y = scaled_data.iloc[:,-1]

# %%
# Implementing Oversampling for Handling Imbalanced 
from imblearn.over_sampling import SMOTE
smk = SMOTE(random_state=42)
x_res,y_res=smk.fit_resample(x,y)
print(x.shape,y.shape)
print(x_res.shape,y_res.shape)
# Out:
# (284807, 30) (284807,)
# (568630, 30) (568630,)

# %%
count_classes = pd.value_counts(y_res, sort = True).sort_index()
count_classes.plot(kind = 'bar')
plt.title("Fraud class histogram")
plt.xlabel("Class")
plt.ylabel("Frequency")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10800\4222904971.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   count_classes = pd.value_counts(y_res, sort = True).sort_index()
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# # BUILDING MODEL

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_res,y_res,test_size=0.2,random_state =42)
model = LogisticRegression()
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
## Checking training accuracy
from sklearn.metrics import accuracy_score,f1_score,precision_score,recall_score,classification_report,confusion_matrix
y_pred_train = model.predict(x_train)
print("The Accuracy of the model is",accuracy_score(y_train,y_pred_train))
print("The Precision of the model is",precision_score(y_train,y_pred_train))
print("The Recall of the model is",recall_score(y_train,y_pred_train))
print("The F1 Score of the model is",f1_score(y_train,y_pred_train))
print("\n")
print(classification_report(y_train,y_pred_train))
# Out:
# The Accuracy of the model is 0.9484308777236515
# The Precision of the model is 0.97400284569101
# The Recall of the model is 0.9214037186756342
# The F1 Score of the model is 0.9469734471667107
#
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95    227565
#            1       0.97      0.92      0.95    227339
#
#     accuracy                           0.95    454904
#    macro avg       0.95      0.95      0.95    454904
# weighted avg       0.95      0.95      0.95    454904

# %%
from yellowbrick.classifier import ConfusionMatrix
cm = ConfusionMatrix(model,classes=["Not Fraud","Fraud"])
cm.fit(x_train,y_train)
cm.score(x_train,y_train)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# 0.9484308777236515

# %%
## Checking the test accuracy 
y_pred_test = model.predict(x_test)
print("The Accuracy of the model is",accuracy_score(y_test,y_pred_test))
print("The Precision of the model is",precision_score(y_test,y_pred_test))
print("The Recall of the model is",recall_score(y_test,y_pred_test))
print("The F1 Score of the model is",f1_score(y_test,y_pred_test))
print("\n")
print(classification_report(y_test,y_pred_test))
# Out:
# The Accuracy of the model is 0.9500553963033959
# The Precision of the model is 0.9741902085490312
# The Recall of the model is 0.9248104465037911
# The F1 Score of the model is 0.9488583159259526
#
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95     56750
#            1       0.97      0.92      0.95     56976
#
#     accuracy                           0.95    113726
#    macro avg       0.95      0.95      0.95    113726
# weighted avg       0.95      0.95      0.95    113726

# %%
## Visualizing the confusion matrix 
from yellowbrick.classifier import ConfusionMatrix
cm1 = ConfusionMatrix(model,classes=["Not Fraud","Fraud"])
cm1.fit(x_test,y_test)
cm1.score(x_test,y_test)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# 0.9500553963033959
